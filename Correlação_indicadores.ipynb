# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import sidrapy
import seaborn as sns
from bcb import sgs
plt.style.use('tableau-colorblind10')
# %matplotlib inline

# %%
data_ini = "2008-01-01"
data_fim = "2024-10-20"

# %%
futures_data = yf.download("CL=F", start=data_ini, end=data_fim)

# Set the index to a datetime type
futures_data.index = pd.to_datetime(futures_data.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_petr = yf.download("PETR4.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_petr.index = pd.to_datetime(stock_petr.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.plot(stock_petr.index,stock_petr['Open'],label='PETR4')
plt.plot(futures_data.index,futures_data['Open'],label='Fut Petro')
plt.legend(loc='upper center', shadow=True, fontsize='10')
# Out:
# /home/zavanin/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# Importa as variações do IPCA
ipca_raw = sidrapy.get_table(table_code = '1737',
                             territorial_level = '1',
                             ibge_territorial_code = 'all',
                             variable = '63,69,2263,2264,2265',
                             period = 'last%20472')

# %%
ipca_raw.index = pd.to_datetime(ipca_raw['D2C'], format='%Y%m', errors='coerce')

# %%
ipca_clean=ipca_raw.loc[ipca_raw['D3C']=='63'][['V','D2C']]

# %%
ipca_clean['V']=pd.to_numeric(ipca_clean['V'])

# %%
plt.plot(ipca_clean['V'][-100:])

# %%
ipca_12m=ipca_raw.loc[ipca_raw['D3C']=='2265'][['V','D2C']]

# %%
ipca_12m['V']=pd.to_numeric(ipca_12m['V'])

# %%
plt.plot(ipca_12m['V'][-100:])

# %%
selic = sgs.get(('selic', 432), start = data_ini)

# %%
# plt.style.use('ggplot')
selic.plot()
# plt.title("Taxa de juros - Meta Selic definida pelo Copom - %a.a")

# %%
plt.plot(selic,label='Selic')
plt.plot(ipca_12m['V'][-200:],label='IPCA-12m')
plt.legend(loc='lower left', shadow=True, fontsize='10')
plt.grid(True)
plt.savefig('selic_ipca_12m.png')

# %%
stock_mypk = yf.download("MYPK3.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_mypk.index = pd.to_datetime(stock_mypk.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_amer = yf.download("AMER3.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_amer.index = pd.to_datetime(stock_amer.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_mglu = yf.download("MGLU3.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_mglu.index = pd.to_datetime(stock_mglu.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_bbas = yf.download("BBAS3.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_bbas.index = pd.to_datetime(stock_bbas.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_hbor = yf.download("HBOR3.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_hbor.index = pd.to_datetime(stock_hbor.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_petz = yf.download("PETZ3.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_petz.index = pd.to_datetime(stock_petz.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_sapr = yf.download("SAPR4.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_sapr.index = pd.to_datetime(stock_sapr.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_cple = yf.download("CPLE6.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_cple.index = pd.to_datetime(stock_cple.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_brsr = yf.download("BRSR6.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_brsr.index = pd.to_datetime(stock_brsr.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_csan = yf.download("CSAN3.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_csan.index = pd.to_datetime(stock_csan.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_cmig = yf.download("CMIG4.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_cmig.index = pd.to_datetime(stock_cmig.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_lren = yf.download("LREN3.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_lren.index = pd.to_datetime(stock_lren.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_klbn = yf.download("KLBN4.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_klbn.index = pd.to_datetime(stock_klbn.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_vale = yf.download("VALE3.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_vale.index = pd.to_datetime(stock_vale.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock_goau = yf.download("GOAU4.SA", start=data_ini, end=data_fim)

# Set the index to a datetime type
stock_goau.index = pd.to_datetime(stock_goau.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dolar = yf.download("USDBRL=X", start=data_ini, end=data_fim)

# Set the index to a datetime type
dolar.index = pd.to_datetime(dolar.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov = yf.download("^BVSP", start=data_ini, end=data_fim)

# Set the index to a datetime type
ibov.index = pd.to_datetime(ibov.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ewz = yf.download("EWZ", start=data_ini, end=data_fim)

# Set the index to a datetime type
ewz.index = pd.to_datetime(ewz.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Importa os dados do SIDRA
pib_sa_raw = sidrapy.get_table(table_code= "1621",
                            territorial_level = "1",
                            ibge_territorial_code = "all",
                            period = "all",
                            classification = "11255/90707")

# Checamos a importação
# pib_sa_raw.head()

# %%
# Substitui as colunas pela primeira observação
pib_sa_raw.columns = pib_sa_raw.iloc[0]

# Retira a primeira observação
pib_sa_raw = pib_sa_raw.iloc[1:, :]

# Altera para float a coluna do valor
pib_sa_raw['Valor'] = pib_sa_raw['Valor'].astype(float)

# %%
# Renomeia e seleciona as colunas de interesse
pib_sa = pib_sa_raw.rename(columns = {"Valor" : "pib_sa",
                                "Trimestre (Código)" : "date"})[['pib_sa', 'date']]

# %%
# Lidar com a coluna de trimestre para transformar em data
pib_sa['date'] = pib_sa['date'].str[:-2] + pib_sa['date'].str[-2:].replace({"01" : "03",
                                                                  "02" : "06",
                                                                  "03" : "09",
                                                                  "04" : "12"})

# %%
# Transforma em formato date a coluna de data e insere no índice
pib_sa.index = pd.to_datetime(pib_sa['date'],
                              format = "%Y%m")

# Retira a coluna de data
pib_sa = pib_sa.drop(columns = ['date'])

# %%
# Importa os dados do pib com ajuste sazonal
pib_raw = sidrapy.get_table(table_code= "1621",
                            territorial_level = "1",
                            ibge_territorial_code= "all",
                            period = "all",
                            classification = "11255/90707")

# %%
# Substitui as colunas pela primeira observação
pib_raw.columns = pib_raw.iloc[0]

# Retira a primeira observação
pib_raw = pib_raw.iloc[1:, :]

# Altera para float a coluna do valor
pib_raw['Valor'] = pib_raw['Valor'].astype(float)

# Renomeia e seleciona as colunas
pib = pib_raw.rename(columns = {"Valor" : "pib",
                                "Trimestre (Código)" : "date"})[['pib', 'date']]


# Procedimento para lidar com a coluna de trimestre para transformar em data
pib['date'] = pib['date'].str[:-2] + pib['date'].str[-2:].replace({"01" : "03",
                                                                  "02" : "06",
                                                                  "03" : "09",
                                                                  "04" : "12"})



# Transforma em formato date a coluna de data e insere no índice
pib.index = pd.to_datetime(pib['date'],
                           format = "%Y%m")

# Retira a coluna de data
pib = pib.drop(columns = ['date'])

# %%
# Junta os dados
pib_df = pd.merge(pib, pib_sa,
         left_index = True, 
         right_index = True)

# %%
# Transforma o data frame de wide para long
pib_df_long = pd.melt(pib_df.reset_index(),
            id_vars = 'date',
            value_vars = ['pib', 'pib_sa'],
            var_name = 'variable',
            value_name = 'values')

# %%
# Configura o tema do gráfico
plt.plot(pib.index,pib['pib'],label='Pib')
# plt.plot(pib_sa.index,pib_sa['pib_sa'],label='Pib_sa')
plt.legend(loc='upper left', shadow=True, fontsize='10')

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(ibov.index,ibov['Open'],label='Ibovespa',color='purple')
ax1.set_xlabel("Data")
ax1.set_ylabel("Valor do Ibovespa em pontos")
ax2.plot(pib.index,pib['pib']/100,label='Pib');
# plt.xlim(pd.Timestamp('2008-01-01'), pd.Timestamp(pib.index[-1]))
ax2.set_ylabel("Valor do Pib em Trilhão de Reais")
ax1.legend()
ax2.legend(loc='upper center')
plt.tight_layout()
ax1.grid(True)
ax2.grid(True)
plt.savefig('Pib_ibov.png')

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(ibov.index,ibov['Open'],label='Ibovespa',color='green')
ax1.set_xlabel("Data")
ax1.set_ylabel("Valor do Ibovespa em pontos")
ax2.plot(dolar.index,dolar['Open'],label='Dolar');
ax2.set_ylabel("Valor do Dólar em Reais")
ax1.legend()
ax2.legend(loc='upper center')
plt.tight_layout()
ax1.grid(True)
ax2.grid(True)
plt.savefig('Dolar_ibov.png')

# %%
plt.plot(dolar.index,dolar['Open'])
# plt.plot(stock_vale.index,stock_vale['Open']/20)
# plt.plot(stock_goau.index,stock_goau['Open']/4)
plt.plot(stock_hbor.index,stock_hbor['Open']/4)
plt.plot(selic)

# %%
dolar.index
# Out:
# DatetimeIndex(['2008-01-01', '2008-01-02', '2008-01-03', '2008-01-04',
#                '2008-01-07', '2008-01-08', '2008-01-09', '2008-01-10',
#                '2008-01-11', '2008-01-14',
#                ...
#                '2024-09-30', '2024-10-01', '2024-10-02', '2024-10-03',
#                '2024-10-04', '2024-10-08', '2024-10-09', '2024-10-10',
#                '2024-10-11', '2024-10-14'],
#               dtype='datetime64[ns]', name='Date', length=4343, freq=None)

# %%
#Agregados monetários

agre_mon=pd.read_csv('meios-de-pagamento.csv')
agre_mon
# Out:
#        DateTime          M1           M2            M3            M4
# 0    2005-03-01  118.560874   503.251673   1027.786068   1145.318592
# 1    2005-04-01  115.498041   503.512158   1033.637671   1152.572654
# 2    2005-05-01  117.556869   505.887925   1040.046083   1161.520593
# 3    2005-06-01  118.793487   513.644026   1050.018485   1174.288144
# 4    2005-07-01  118.562751   518.947452   1070.923797   1195.820490
# ..          ...         ...          ...           ...           ...
# 228  2024-03-01  605.349163  5969.478261  11200.866302  12309.364664
# 229  2024-04-01  619.328956  6010.176412  11212.545058  12367.703039
# 230  2024-05-01  654.661444  6113.142610  11392.408823  12560.117959
# 231  2024-06-01  671.152601  6265.713908  11582.099190  12799.890385
# 232  2024-07-01  648.919916  6289.696260  11677.419197  12913.276064
#
# [233 rows x 5 columns]

# %%
agre_mon['DateTime'] = pd.to_datetime(agre_mon['DateTime'])

# %%
agre_mon.set_index('DateTime', inplace=True)

# %%
agre_mon.index
# Out:
# DatetimeIndex(['2005-03-01', '2005-04-01', '2005-05-01', '2005-06-01',
#                '2005-07-01', '2005-08-01', '2005-09-01', '2005-10-01',
#                '2005-11-01', '2005-12-01',
#                ...
#                '2023-10-01', '2023-11-01', '2023-12-01', '2024-01-01',
#                '2024-02-01', '2024-03-01', '2024-04-01', '2024-05-01',
#                '2024-06-01', '2024-07-01'],
#               dtype='datetime64[ns]', name='DateTime', length=233, freq=None)

# %%
plt.plot(agre_mon.index,agre_mon['M1'],label='M1')
plt.plot(agre_mon.index,agre_mon['M2'],label='M2')
plt.plot(agre_mon.index,agre_mon['M3'],label='M3')
plt.plot(agre_mon.index,agre_mon['M4'],label='M4')
plt.xlabel('Data')
plt.ylabel("R$ Bilhões")
plt.legend(loc='upper left')
plt.tight_layout()
plt.grid(True)
plt.savefig('agregados.png')

# %%
agre_mon['M1_dif']=agre_mon['M1'].pct_change()
agre_mon['M2_dif']=agre_mon['M2'].pct_change()
agre_mon['M3_dif']=agre_mon['M3'].pct_change()
agre_mon['M4_dif']=agre_mon['M4'].pct_change()

# %%
agre_mon
# Out:
#                     M1           M2            M3            M4    M1_dif  \
# DateTime
# 2005-03-01  118.560874   503.251673   1027.786068   1145.318592       NaN
# 2005-04-01  115.498041   503.512158   1033.637671   1152.572654 -0.025833
# 2005-05-01  117.556869   505.887925   1040.046083   1161.520593  0.017826
# 2005-06-01  118.793487   513.644026   1050.018485   1174.288144  0.010519
# 2005-07-01  118.562751   518.947452   1070.923797   1195.820490 -0.001942
# ...                ...          ...           ...           ...       ...
# 2024-03-01  605.349163  5969.478261  11200.866302  12309.364664  0.010383
# 2024-04-01  619.328956  6010.176412  11212.545058  12367.703039  0.023094
# 2024-05-01  654.661444  6113.142610  11392.408823  12560.117959  0.057050
# 2024-06-01  671.152601  6265.713908  11582.099190  12799.890385  0.025190
# 2024-07-01  648.919916  6289.696260  11677.419197  12913.276064 -0.033126
#
#               M2_dif    M3_dif    M4_dif
# DateTime
# ...

# %%
plt.plot(agre_mon.index,agre_mon['M1_dif'],label='M1_dif')
plt.plot(agre_mon.index,agre_mon['M2_dif'],label='M2_dif')
plt.plot(agre_mon.index,agre_mon['M3_dif'],label='M3_dif')
plt.plot(agre_mon.index,agre_mon['M4_dif'],label='M4_dif')

# %%
agre_mon['M1_12m']=agre_mon['M1_dif'].rolling(12, min_periods=12).sum()
agre_mon['M2_12m']=agre_mon['M2_dif'].rolling(12, min_periods=12).sum()
agre_mon['M3_12m']=agre_mon['M3_dif'].rolling(12, min_periods=12).sum()
agre_mon['M4_12m']=agre_mon['M4_dif'].rolling(12, min_periods=12).sum()

# %%
agre_mon
# Out:
#                     M1           M2            M3            M4    M1_dif  \
# DateTime
# 2005-03-01  118.560874   503.251673   1027.786068   1145.318592       NaN
# 2005-04-01  115.498041   503.512158   1033.637671   1152.572654 -0.025833
# 2005-05-01  117.556869   505.887925   1040.046083   1161.520593  0.017826
# 2005-06-01  118.793487   513.644026   1050.018485   1174.288144  0.010519
# 2005-07-01  118.562751   518.947452   1070.923797   1195.820490 -0.001942
# ...                ...          ...           ...           ...       ...
# 2024-03-01  605.349163  5969.478261  11200.866302  12309.364664  0.010383
# 2024-04-01  619.328956  6010.176412  11212.545058  12367.703039  0.023094
# 2024-05-01  654.661444  6113.142610  11392.408823  12560.117959  0.057050
# 2024-06-01  671.152601  6265.713908  11582.099190  12799.890385  0.025190
# 2024-07-01  648.919916  6289.696260  11677.419197  12913.276064 -0.033126
#
# ...

# %%
plt.plot(agre_mon.index,agre_mon['M1_12m'],label='M1_12m')
plt.plot(agre_mon.index,agre_mon['M2_12m'],label='M2_12m')
# plt.plot(agre_mon.index,agre_mon['M3_12m'],label='M3_12m')
# plt.plot(agre_mon.index,agre_mon['M4_12m'],label='M4_12m')
plt.plot(ipca_12m['V'][-220:]/100,label='IPCA_12m')
plt.xlabel('Data')
# plt.ylabel("%")
plt.legend(loc='upper center')
plt.tight_layout()
plt.grid(True)
plt.savefig('percent_agreg_ipca.png')

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(ibov.index,ibov['Open'],label='Ibovespa',color='green')
ax1.set_xlabel("Data")
ax1.set_ylabel("Valor do Ibovespa em pontos")
# ax2.plot(dolar.index,dolar['Open'],label='Dolar');
ax2.plot(ewz.index,ewz['Open'],label='EWZ');
ax2.set_ylabel("Valor do EWZ em Reais")
ax1.legend()
ax2.legend(loc='upper center')
plt.tight_layout()
ax1.grid(True)
ax2.grid(True)
plt.savefig('ewz_ibov.png')

# %%
from pandas_datareader import DataReader

# %%
gdp = DataReader("GDP", "fred", 1948, 2022).dropna()

# %%
plt.plot(pib/100)
plt.plot(gdp[-100:]/1000)

# %%
plt.plot(stock_bbas.index,stock_bbas['Open'],label='BBAS3')
# plt.plot(stock_hbor.index,stock_hbor['Open']/4,label='HBOR/4')
# plt.plot(stock_lren.index,stock_lren['Open']/6,label='LREN3/6')
# plt.plot(stock_sapr.index,stock_sapr['Open'],label='SAPR4')
# plt.plot(stock_goau.index,stock_goau['Open'],label='GOAU4')
# plt.plot(stock_petz.index,stock_petz['Open']/4)
# plt.plot(stock_amer.index,stock_amer['Open']/10)
# plt.plot(stock_mglu.index,stock_mglu['Open']/2)
plt.plot(stock_klbn.index,stock_klbn['Open'],label='KLBN4')
plt.plot(stock_csan.index,stock_csan['Open'],label='CSAN4')
# plt.plot(stock_brsr.index,stock_brsr['Open']/4,label='BRSR6/4')
plt.plot(stock_cple.index,stock_cple['Open'],label='CPLE6')
# plt.plot(stock_cmig[-3000:].index,stock_cmig[-3000:]['Open'],label='CMIG4')
# plt.plot(dolar.index,dolar['Open'],label='Dolar')
# plt.plot(pib[-66:].index,pib[-66:]['pib']/50,label='Pib/50')
# plt.plot(gdp[-65:]/1000,label='GDP/100')
# plt.plot(ipca_12m['V'][-200:],label='IPCA_12M')
plt.plot(selic,label='Selic')
plt.legend(loc='upper left', shadow=True, fontsize='10')
plt.grid(True)
plt.savefig('emps_selic.png')

# %%
data_frames = [stock_goau['Open'].rename('GOAU4'),stock_klbn['Open'].rename('KLBN4'), stock_bbas['Open'].rename('BBAS3'),stock_hbor['Open'].rename('HBOR3'),stock_mypk['Open'].rename('MYPK3'),stock_sapr['Open'].rename('SAPR4'),stock_cple['Open'].rename('CPLE6'),stock_brsr['Open'].rename('BRSR6'),stock_csan['Open'].rename('CSAN3'),stock_cmig['Open'].rename('CMIG4'),stock_lren['Open'].rename('LREN3'),stock_petr['Open'].rename('PETR4'),stock_vale['Open'].rename('VALE3')]

# %%
from functools import reduce
df_corr_pre = reduce(lambda  left,right: pd.merge(left,right,on=['Date'],
                                            how='inner'), data_frames)
corr=df_corr_pre.corr(method='spearman').round(2)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8ac1e982_8a26_11ef_a172_4358f1701771row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8ac1e982_8a26_11ef_a172_4358f1701771row0_col1 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_8ac1e982_8a26_11ef_a172_4358f1701771row0_col2 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_8ac1e982_8a26_11ef_a172_4358f1701771row0_col3 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_8ac1e982_8a26_11ef_a172_4358f1701771row0_col4 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_8ac1e982_8a26_11ef_a172_4358f1701771row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8ac1e982_8a26_11ef_a172_4358f1701771row0_col6 {
#             background-color:  #98b9ff;
#             color:  #000000;
# ...

# %%
fig, ax = plt.subplots()
sns.heatmap(corr,annot=True, fmt='.2f', 
            cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax)
ax.set_yticklabels(ax.get_yticklabels(), rotation="horizontal")
# plt.savefig('corr.png', bbox_inches='tight', pad_inches=0.0)
# Out:
# [Text(0, 0.5, 'GOAU4'),
#  Text(0, 1.5, 'KLBN4'),
#  Text(0, 2.5, 'BBAS3'),
#  Text(0, 3.5, 'HBOR3'),
#  Text(0, 4.5, 'MYPK3'),
#  Text(0, 5.5, 'SAPR4'),
#  Text(0, 6.5, 'CPLE6'),
#  Text(0, 7.5, 'BRSR6'),
#  Text(0, 8.5, 'CSAN3'),
#  Text(0, 9.5, 'CMIG4'),
#  Text(0, 10.5, 'LREN3'),
#  Text(0, 11.5, 'PETR4'),
#  Text(0, 12.5, 'VALE3')]

# %%
df_corr_pre.groupby(by=[df_corr_pre.index.year]).agg(["var"])
# Out:
#            GOAU4     KLBN4      BBAS3      HBOR3      MYPK3     SAPR4  \
#              var       var        var        var        var       var
# Date
# 2008  146.065637  0.053902   7.987177  16.694765  26.782899  0.031140
# 2009    9.635011  0.001590   2.114179   1.849404   0.726235  0.001219
# 2010    8.678625  0.002692   0.584025   8.032413   6.349439  0.002744
# 2011   14.956009  0.015654   1.448521   2.079459   3.439720  0.022402
# 2012    2.369564  0.067781   1.912127  31.066276  15.567391  0.145290
# 2013    5.574178  0.037977   1.059317   9.738251   2.453053  0.161892
# 2014    7.670583  0.020264   3.664070  17.605659  12.666140  0.013732
# 2015   13.454534  0.169661   2.874076  19.303092   3.672387  0.052842
# 2016    1.755491  0.102346   5.452442   2.556707   7.659350  0.711154
# 2017    0.314717  0.064547   1.977031   2.861935  10.460390  0.164288
# 2018    0.330447  0.015530   8.184160   3.014123   4.867047  0.092983
# ...

# %%
df_var=df_corr_pre.groupby(by=[df_corr_pre.index.year,df_corr_pre.index.month]).agg(["var",'mean'])

# %%
names = ['GOAU4','KLBN4','BBAS3','HBOR3','MYPK3','SAPR4','CPLE6','BRSR6','CSAN3','CMIG4','LREN3']

# %%
empty_list=[]
for i in names:
    col=df_var[i]['var']/df_var[i]['mean']
    res=pd.DataFrame(col).rename({0:i},axis=1)
    empty_list.append(res)

# %%
var_month=pd.concat(empty_list,axis=1)

# %%
var_month.loc[var_month.index.isin(var_month.index[-12:])]
# Out:
#               GOAU4     KLBN4     BBAS3     HBOR3     MYPK3     SAPR4  \
# Date Date
# 2023 11    0.022392  0.002135  0.011069  0.011696  0.004815  0.013626
#      12    0.003332  0.001889  0.004235  0.008949  0.012668  0.008181
# 2024 1     0.014253  0.000731  0.006954  0.020577  0.005649  0.001916
#      2     0.001369  0.001425  0.005166  0.005097  0.010721  0.005719
#      3     0.002840  0.008897  0.008735  0.002922  0.021281  0.000763
#      4     0.002879  0.003522  0.010874  0.007950  0.041301  0.001434
#      5     0.006178  0.001011  0.005353  0.011141  0.045261  0.005428
#      6     0.004804  0.001013  0.006310  0.004675  0.023846  0.002721
#      7     0.004643  0.001130  0.003365  0.004641  0.008646  0.001083
#      8     0.005034  0.002587  0.036815  0.002072  0.006896  0.001035
#      9     0.002684  0.001334  0.012849  0.002261  0.007809  0.010681
#      10    0.001399  0.000116  0.000578  0.000296  0.001562  0.000298
#
# ...
